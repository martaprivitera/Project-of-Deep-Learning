# %% [markdown]
# # VGG

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Dataset download

# %%
import urllib.request
import tarfile

# URL dataset
url = "http://download.tensorflow.org/example_images/flower_photos.tgz"

# Download destination path
file_name = "flower_photos.tgz"

# File download
urllib.request.urlretrieve(url, file_name)

# File extraction
tar = tarfile.open(file_name)
tar.extractall()
tar.close()

# %% [markdown]
# Dataset split into train (0.7), validation (0.2) and test set (0.1)

# %%
# !pip install split-folders
import splitfolders
splitfolders.ratio('flower_photos', output="output", seed=1337, ratio=(0.7, 0.2, 0.1))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Copying files: 3670 files [00:00, 3859.02 files/s]

# %% [markdown]
# Libraries import

# %%
import tensorflow as tf
from tensorflow import keras

from matplotlib import pyplot as plt
import numpy as np

import random as python_random

from tensorflow.keras import layers
from tensorflow.keras.applications.vgg16 import VGG16

# %% [markdown]
# Set the seeds

# %%
np.random.seed(0)
python_random.seed(0)
tf.random.set_seed(0)

# %% [markdown]
# Path for train, validation and test set

# %%
path_train='/content/output/train/'
path_val='/content/output/val/'
path_test='/content/output/test/'

# %% [markdown]
# Saving train, validation and test set

# %%
train_dataset = keras.preprocessing.image_dataset_from_directory(path_train,
                                                            image_size=(224,224),
                                                            batch_size=32,
                                                            label_mode='categorical',
                                                            validation_split = False,
                                                            shuffle=True,
                                                            seed=1)

val_dataset = keras.preprocessing.image_dataset_from_directory(path_val,
                                                            image_size=(224,224),
                                                            batch_size=32,
                                                            label_mode='categorical',
                                                            validation_split = False,
                                                            shuffle=True,
                                                            seed=1)

test_dataset = keras.preprocessing.image_dataset_from_directory(path_test,
                                                            image_size=(224,224),
                                                            batch_size=32,
                                                            label_mode='categorical',
                                                            validation_split = False,
                                                            shuffle=True,
                                                            seed=1)
# Out:
# Found 2567 files belonging to 5 classes.
# Found 731 files belonging to 5 classes.
# Found 372 files belonging to 5 classes.

# %%
class_names = train_dataset.class_names
print(class_names)
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %% [markdown]
# Data augmentation

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.1),
    ]
)

# %%
num_classes=5

# %% [markdown]
# We fix two values among: learning rate, dense nodes, regularizer and we let the other parameter changes in order to see which is the best model for our dataset.
# We start by changing learning rate, then regularizer and then dense nodes. When we have checked which is the best value for each parameter, we fixed it.
# We do that for both optimizer Adam and RMSprop.

# %% [markdown]
# # Net with optimizer Adam and variable Learning rate
# - reg: 0.001
# - dense: 512

# %%
# learning rate
lr_values = [0.01, 0.001, 0.0001]

histories_Adam_lr = []
evaluate_test = []

for lr in lr_values:
    # Create the model
    vgg_model = keras.applications.VGG16(input_shape=(224,224,3), weights='imagenet', include_top=False)


    for layer in vgg_model.layers:
        layer.trainable = False

    from keras import regularizers

    inputs = keras.Input(shape=(224, 224, 3))
    x = inputs
    x = data_augmentation(x)
    x = keras.applications.vgg16.preprocess_input(x)
    x = vgg_model(x)
    x = keras.layers.GlobalAveragePooling2D()(x)

    x = keras.layers.BatchNormalization()(x)

    x = keras.layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
    x = keras.layers.Dropout(0.5)(x)
    x = keras.layers.BatchNormalization()(x)
    outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
    net_Adam_lr = keras.Model(inputs=inputs, outputs=outputs)

    from tensorflow.keras.optimizers import Adam
    # Compile the model
    net_Adam_lr.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=Adam(learning_rate=lr),
              metrics=['accuracy'])

    net_Adam_lr.summary()

    callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

    # Train the model
    history_Adam_lr = net_Adam_lr.fit(train_dataset,
          epochs=40,
          validation_data=val_dataset,
          callbacks=[callback])

    evaluate = loss, accuracy = net_Adam_lr.evaluate(test_dataset)

    evaluate_test.append(evaluate)

    net_Adam_lr.save('gdrive/MyDrive/FDL/Vgg_Adam_lr_{}.h5'.format(lr))

    histories_Adam_lr.append(history_Adam_lr)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  dense (Dense)               (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_1 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 14,984,005
# Trainable params: 267,269
# Non-trainable params: 14,716,736
# _________________________________________________________________
# Epoch 1/40
# 81/81 [==============================] -
40
# 81/81 [==============================] - 15s 186ms/step - loss: 0.7712 - accuracy: 0.8792 - val_loss: 0.8282 - val_accuracy: 0.8728
# Epoch 30/40
# 81/81 [==============================] - 15s 186ms/step - loss: 0.7639 - accuracy: 0.8859 - val_loss: 0.8288 - val_accuracy: 0.8728
# Epoch 31/40
# 81/81 [==============================] - 17s 188ms/step - loss: 0.7649 - accuracy: 0.8777 - val_loss: 0.8239 - val_accuracy: 0.8755
# Epoch 32/40
# 81/81 [==============================] - 16s 191ms/step - loss: 0.7440 - accuracy: 0.8901 - val_loss: 0.8221 - val_accuracy: 0.8728
# Epoch 33/40
# 81/81 [==============================] - 16s 191ms/step - loss: 0.7339 - accuracy: 0.8905 - val_loss: 0.8251 - val_accuracy: 0.8714
# Epoch 34/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.7179 - accuracy: 0.8979 - val_loss: 0.8210 - val_accuracy: 0.8700
# Epoch 35/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.7141 - accuracy: 0.9038 - val_loss: 0.8112 - val_accuracy: 0.8769
# Epoch 36/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.7079 - accuracy: 0.9014 - val_loss: 0.8123 - val_accuracy: 0.8741
# Epoch 37/40
# 81/81 [==============================] - 17s 202ms/step - loss: 0.7019 - accuracy: 0.8960 - val_loss: 0.8082 - val_accuracy: 0.8714
# Epoch 38/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.6956 - accuracy: 0.9038 - val_loss: 0.8009 - val_accuracy: 0.8741
# Epoch 39/40
# 81/81 [==============================] - 17s 207ms/step - loss: 0.6886 - accuracy: 0.9057 - val_loss: 0.7983 - val_accuracy: 0.8769
# Epoch 40/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.6967 - accuracy: 0.8999 - val_loss: 0.7982 - val_accuracy: 0.8769
# 12/12 [==============================] - 2s 135ms/step - loss: 0.7002 - accuracy: 0.9059

# %%
evaluate_test
# Out:
# [[1.015032172203064, 0.8763440847396851],
#  [0.5926646590232849, 0.8897849321365356],
#  [0.7001518607139587, 0.9059139490127563]]

# %%
import pandas as pd


table_data = {'Learning Rate': lr_values, 'Loss Diff Mean': [], 'Accuracy Diff Mean': []}

for i, history in enumerate(histories_Adam_lr):
    lr = lr_values[i]

    train_loss_diff = np.abs(np.array(history.history['loss']) - np.array(history.history['val_loss']))
    avg_loss_diff = np.mean(train_loss_diff)


    train_acc_diff = np.abs(np.array(history.history['accuracy']) - np.array(history.history['val_accuracy']))
    avg_acc_diff = np.mean(train_acc_diff)


    table_data['Accuracy Diff Mean'].append(avg_acc_diff)
    table_data['Loss Diff Mean'].append(avg_loss_diff)

    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.ylim([0, 2.0])
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['train', 'valid'])
    plt.title(f'Training and Validation Loss (learning rate = {lr})');


    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.ylim([0.5, 1.0])
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['train', 'valid'])
    plt.title(f'Training and Validation Accuracy (learning rate = {lr})');

    plt.tight_layout()
    plt.show()


table_df = pd.DataFrame(table_data)


print(table_df.to_string(index=False, float_format='%.4f'))
# Out:
#  Learning Rate  Loss Diff Mean  Accuracy Diff Mean
#         0.0100          0.0933              0.0407
#         0.0010          0.1473              0.0381
#         0.0001          0.0946              0.0329

# %% [markdown]
# # Net with optimizer RMSprop and learning rate variable
# - dense: 512
# - reg: 0.001

# %%
# variable learning rate values
lr_values = [0.01, 0.001, 0.0001]


histories_RMS_lr = []
evaluate_test = []

for lr in lr_values:
    # Create the model
    vgg_model = keras.applications.VGG16(input_shape=(224,224,3), weights='imagenet', include_top=False)


    for layer in vgg_model.layers:
        layer.trainable = False

    from keras import regularizers

    inputs = keras.Input(shape=(224, 224, 3))
    x = inputs
    x = data_augmentation(x)
    x = keras.applications.vgg16.preprocess_input(x)
    x = vgg_model(x)
    x = keras.layers.GlobalAveragePooling2D()(x)


    x = keras.layers.BatchNormalization()(x)

    x = keras.layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
    x = keras.layers.Dropout(0.5)(x)
    x = keras.layers.BatchNormalization()(x)
    outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
    net_RMS_lr = keras.Model(inputs=inputs, outputs=outputs)


    # Compile the model
    net_RMS_lr.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.RMSprop(learning_rate=lr),
              metrics=['accuracy'])

    net_RMS_lr.summary()

    callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

    # train the model
    history_RMS_lr = net_RMS_lr.fit(train_dataset,
          epochs=40,
          validation_data=val_dataset,
          callbacks=[callback])

    evaluate = loss, accuracy = net_RMS_lr.evaluate(test_dataset)
    evaluate_test.append(evaluate)

    net_RMS_lr.save('drive/MyDrive/FDL/Vgg_RMS_lr_{}.h5'.format(lr))

    histories_RMS_lr.append(history_RMS_lr)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem_3   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_3 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d_3   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_6 (Dense)             (None, 512)               262656
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  batch_normalization_7 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_7 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 14,984,005
# Trainable params: 267,269
# Non-trainable params: 14,716,736
# _________________________________________________________________
# Epoch 1/40
# 81/81 [==============================] -
40
# 81/81 [==============================] - 16s 191ms/step - loss: 0.8113 - accuracy: 0.8703 - val_loss: 0.8268 - val_accuracy: 0.8782
# Epoch 23/40
# 81/81 [==============================] - 17s 208ms/step - loss: 0.8056 - accuracy: 0.8675 - val_loss: 0.8283 - val_accuracy: 0.8796
# Epoch 24/40
# 81/81 [==============================] - 17s 201ms/step - loss: 0.8031 - accuracy: 0.8711 - val_loss: 0.8243 - val_accuracy: 0.8810
# Epoch 25/40
# 81/81 [==============================] - 19s 227ms/step - loss: 0.7949 - accuracy: 0.8644 - val_loss: 0.8140 - val_accuracy: 0.8837
# Epoch 26/40
# 81/81 [==============================] - 18s 210ms/step - loss: 0.7877 - accuracy: 0.8781 - val_loss: 0.8160 - val_accuracy: 0.8810
# Epoch 27/40
# 81/81 [==============================] - 17s 207ms/step - loss: 0.7563 - accuracy: 0.8882 - val_loss: 0.8154 - val_accuracy: 0.8851
# Epoch 28/40
# 81/81 [==============================] - 17s 204ms/step - loss: 0.7312 - accuracy: 0.8933 - val_loss: 0.8071 - val_accuracy: 0.8769
# Epoch 29/40
# 81/81 [==============================] - 18s 222ms/step - loss: 0.7257 - accuracy: 0.8913 - val_loss: 0.7973 - val_accuracy: 0.8796
# Epoch 30/40
# 81/81 [==============================] - 17s 204ms/step - loss: 0.7224 - accuracy: 0.8956 - val_loss: 0.7997 - val_accuracy: 0.8796
# Epoch 31/40
# 81/81 [==============================] - 16s 193ms/step - loss: 0.7352 - accuracy: 0.8929 - val_loss: 0.7996 - val_accuracy: 0.8741
# Epoch 32/40
# 81/81 [==============================] - 15s 184ms/step - loss: 0.7091 - accuracy: 0.8999 - val_loss: 0.7956 - val_accuracy: 0.8782
# Epoch 33/40
# 81/81 [==============================] - 15s 184ms/step - loss: 0.6975 - accuracy: 0.8975 - val_loss: 0.7961 - val_accuracy: 0.8796
# Epoch 34/40
# 81/81 [==============================] - 16s 191ms/step - loss: 0.7124 - accuracy: 0.8921 - val_loss: 0.7888 - val_accuracy: 0.8782
# Epoch 35/40
# 81/81 [==============================] - 16s 189ms/step - loss: 0.6882 - accuracy: 0.8979 - val_loss: 0.7861 - val_accuracy: 0.8755
# Epoch 36/40
# 81/81 [==============================] - 15s 184ms/step - loss: 0.6823 - accuracy: 0.8991 - val_loss: 0.7832 - val_accuracy: 0.8810
# Epoch 37/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.6722 - accuracy: 0.9046 - val_loss: 0.7773 - val_accuracy: 0.8824
# Epoch 38/40
# 81/81 [==============================] - 16s 188ms/step - loss: 0.6635 - accuracy: 0.9057 - val_loss: 0.7714 - val_accuracy: 0.8796
# Epoch 39/40
# 81/81 [==============================] - 15s 186ms/step - loss: 0.6905 - accuracy: 0.8917 - val_loss: 0.7701 - val_accuracy: 0.8769
# Epoch 40/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.6596 - accuracy: 0.9042 - val_loss: 0.7694 - val_accuracy: 0.8741
# 12/12 [==============================] - 2s 136ms/step - loss: 0.7083 - accuracy: 0.8978

# %%
evaluate_test
# Out:
# [[0.615871012210846, 0.8844085931777954],
#  [0.4889935255050659, 0.9005376100540161],
#  [0.7083141207695007, 0.897849440574646]]

# %%
import pandas as pd


table_data = {'Learning Rate': lr_values, 'Loss Diff Mean': [], 'Accuracy Diff Mean': []}

for i, history in enumerate(histories_RMS_lr):
    lr = lr_values[i]

    train_loss_diff = np.abs(np.array(history.history['loss']) - np.array(history.history['val_loss']))
    avg_loss_diff = np.mean(train_loss_diff)


    train_acc_diff = np.abs(np.array(history.history['accuracy']) - np.array(history.history['val_accuracy']))
    avg_acc_diff = np.mean(train_acc_diff)



    table_data['Accuracy Diff Mean'].append(avg_acc_diff)
    table_data['Loss Diff Mean'].append(avg_loss_diff)

    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.ylim([0, 2.0])
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['train', 'valid'])
    plt.title(f'Training and Validation Loss (learning rate = {lr})');


    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.ylim([0.5, 1.0])
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['train', 'valid'])
    plt.title(f'Training and Validation Accuracy (learning rate = {lr})');

    plt.tight_layout()
    plt.show()



table_df = pd.DataFrame(table_data)


print(table_df.to_string(index=False, float_format='%.4f'))
# Out:
#  Learning Rate  Loss Diff Mean  Accuracy Diff Mean
#         0.0100          0.0612              0.0283
#         0.0010          0.2024              0.0379
#         0.0001          0.1014              0.0364

# %% [markdown]
# # Adam vs RMSprop graphs with different learning rate values
# - comparison between models with different values of learning rate

# %%
plt.figure(figsize=(12, 10))

plt.subplot(2, 2, 1)

for i, history in enumerate(histories_Adam_lr):
    plt.plot(history.history['val_loss'], label='Learning rate {}'.format(lr_values[i]))
plt.ylim([0, 2.0])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Loss (Adam)')
plt.legend()



plt.subplot(2, 2, 2)
for i, history in enumerate(histories_RMS_lr):
    plt.plot(history.history['val_loss'], label='Learning rate {}'.format(lr_values[i]))
plt.ylim([0, 2.0])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Loss (RMS)')
plt.legend()



plt.subplot(2, 2, 3)
for i, history in enumerate(histories_Adam_lr):
    plt.plot(history.history['val_accuracy'], label='Learning rate {}'.format(lr_values[i]))
plt.ylim([0.5, 1.0])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Accuracy (Adam)')
plt.legend()



plt.subplot(2, 2, 4)
for i, history in enumerate(histories_RMS_lr):
    plt.plot(history.history['val_accuracy'], label='Learning rate {}'.format(lr_values[i]))
plt.ylim([0.5, 1.0])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Accuracy (RMS)')
plt.legend()

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(histories_Adam_lr[1].history['val_loss'], label='Adam, Learning rate {}'.format(lr_values[1]))
plt.plot(histories_RMS_lr[1].history['val_loss'], label='RMS, Learning rate {}'.format(lr_values[1]))
plt.ylim([0, 1])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Loss Adam vs RMS')
plt.legend()



plt.subplot(1, 2, 2)
plt.plot(histories_Adam_lr[1].history['val_accuracy'], label='Adam, Learning rate {}'.format(lr_values[1]))
plt.plot(histories_RMS_lr[1].history['val_accuracy'], label='RMS, Learning rate {}'.format(lr_values[1]))
plt.ylim([0.5, 1.0])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Accuracy Adam vs RMS')
plt.legend()

# %% [markdown]
# For the following models we fix learning rate = 0.001 for both Adam and RMSprop optimizer

# %% [markdown]
# # Net with optimizer Adam and variable regularizer
# - dense: 512
# - learning rate: 0.001

# %%
# regularizer values
reg_values = [0.1, 0.01, 0.001, 0.0001]


histories_Adam_reg = []
evaluate_test = []

for reg in reg_values:
    # Create the model
    vgg_model = keras.applications.VGG16(input_shape=(224,224,3), weights='imagenet', include_top=False)


    for layer in vgg_model.layers:
        layer.trainable = False

    from keras import regularizers

    inputs = keras.Input(shape=(224, 224, 3))
    x = inputs
    x = data_augmentation(x)
    x = keras.applications.vgg16.preprocess_input(x)
    x = vgg_model(x)
    x = keras.layers.GlobalAveragePooling2D()(x)


    x = keras.layers.BatchNormalization()(x)

    x = keras.layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(reg))(x)
    x = keras.layers.Dropout(0.5)(x)
    x = keras.layers.BatchNormalization()(x)
    outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
    net_Adam_reg = keras.Model(inputs=inputs, outputs=outputs)

    from tensorflow.keras.optimizers import Adam
    # Compile the model
    net_Adam_reg.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy'])


    net_Adam_reg.summary()


    callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

    # train the model
    history_Adam_reg = net_Adam_reg.fit(train_dataset,
          epochs=40,
          validation_data=val_dataset,
          callbacks=[callback])

    evaluate = loss, accuracy = net_Adam_reg.evaluate(test_dataset)
    evaluate_test.append(evaluate)

    net_Adam_reg.save('drive/MyDrive/FDL/Vgg_Adam_reg_{}.h5'.format(reg))

    histories_Adam_reg.append(history_Adam_reg)
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem_6   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_6 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d_6   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  batch_normalization_12 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_12 (Dense)            (None, 512)               262656
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  batch_normalization_13 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_13 (Dense)            (None, 5)                 2565
#
# =================================================================
# Total params: 14,984,005
# Trainable params: 267,269
# Non-trainable params: 14,716,736
# _________________________________________________________________
# Epoch 1/40
# 81/81 [==============================] - 17s 177ms/step - loss: 21.2667 - accuracy: 0.6821 - val_loss: 5.5602 - val_accuracy: 0.8057
# Epoch 2/40
# 81/81 [==============================] - 15s 180ms/step - loss: 3.2474 - accuracy: 0.7776 - val_loss: 2.0012 - val_accuracy: 0.8276
# Epoch 3/40
# 81/81 [==============================] - 15s 183ms/step - loss: 1.8646 - accuracy: 0.7900 - val_loss: 1.5593 - val_accuracy: 0.8386
# Epoch 4/40
# 81/81 [==============================] - 15s 179ms/step - loss: 1.6479 - accuracy: 0.7959 - val_loss: 1.5073 - val_accuracy: 0.8263
# Epoch 5/40
# 81/81 [==============================] - 17s 200ms/step - loss: 1.5713 - accuracy: 0.7994 - val_loss: 1.4502 - val_accuracy: 0.8413
# Epoch 6/40
# 81/81 [==============================] - 16s 186ms/step - loss: 1.5058 - accuracy: 0.7931 - val_loss: 1.4103 - val_accuracy: 0.8468
# Epoch 7/40
# 81/81 [==============================] - 15s 182ms/step - loss: 1.4812 - accuracy: 0.7974 - val_loss: 1.3762 - val_accuracy: 0.8591
# Epoch 8/40
# 81/81 [==============================] - 15s 184ms/step - loss: 1.5123 - accuracy: 0.7943 - val_loss: 1.3814 - val_accuracy: 0.8386
# Epoch 9/40
# 81/81 [==============================] - 15s 184ms/step - loss: 1.5071 - accuracy: 0.8037 - val_loss: 1.3727 - val_accuracy: 0.8468
# Epoch 10/40
# 81/81 [==============================] - 16s 183ms/step - loss: 1.4626 - accuracy: 0.8103 - val_loss: 1.4161 - val_accuracy: 0.8263
# Epoch 11/40
# 81/81 [==============================] - 15s 181ms/step - loss: 1.4152 - accuracy: 0.8021 - val_loss: 1.2691 - val_accuracy: 0.8632
# Epoch 12/40
# 81/81 [==============================] - 15s 184ms/step - loss: 1
40
# 81/81 [==============================] - 16s 187ms/step - loss: 0.6523 - accuracy: 0.9014 - val_loss: 0.7618 - val_accuracy: 0.8728
# Epoch 12/40
# 81/81 [==============================] - 15s 185ms/step - loss: 0.6334 - accuracy: 0.8999 - val_loss: 0.7546 - val_accuracy: 0.8659
# Epoch 13/40
# 81/81 [==============================] - 15s 184ms/step - loss: 0.6015 - accuracy: 0.9085 - val_loss: 0.7455 - val_accuracy: 0.8714
# Epoch 14/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.6073 - accuracy: 0.9061 - val_loss: 0.7560 - val_accuracy: 0.8673
# Epoch 15/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.6184 - accuracy: 0.8905 - val_loss: 0.7161 - val_accuracy: 0.8769
# Epoch 16/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.5882 - accuracy: 0.9011 - val_loss: 0.7374 - val_accuracy: 0.8618
# Epoch 17/40
# 81/81 [==============================] - 17s 204ms/step - loss: 0.5533 - accuracy: 0.9174 - val_loss: 0.7612 - val_accuracy: 0.8605
# Epoch 18/40
# 81/81 [==============================] - 16s 187ms/step - loss: 0.5533 - accuracy: 0.9131 - val_loss: 0.7270 - val_accuracy: 0.8810
# Epoch 19/40
# 81/81 [==============================] - 15s 185ms/step - loss: 0.5386 - accuracy: 0.9123 - val_loss: 0.7458 - val_accuracy: 0.8673
# Epoch 20/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.5356 - accuracy: 0.9213 - val_loss: 0.7289 - val_accuracy: 0.8796
# 12/12 [==============================] - 2s 133ms/step - loss: 0.6224 - accuracy: 0.8978
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem_9   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_9 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d_9   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  batch_normalization_18 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_18 (Dense)            (None, 512)               262656
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  batch_normalization_19 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_19 (Dense)            (None, 5)                 2565
#
# =================================================================
# Total params: 14,984,005
# Trainable params: 267,269
# Non-trainable params: 14,716,736
# _________________________________________________________________
# Epoch 1/40
# 81/81 [==============================] - 20s 206ms/step - loss: 0.9387 - accuracy: 0.6743 - val_loss: 0.5437 - val_accuracy: 0.8440
# Epoch 2/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.5855 - accuracy: 0.8068 - val_loss: 0.4877 - val_accuracy: 0.8659
# Epoch 3/40
# 81/81 [==============================] - 15s 184ms/step - loss: 0.4964 - accuracy: 0.8379 - val_loss: 0.4217 - val_accuracy: 0.8769
# Epoch 4/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.4263 - accuracy: 0.8637 - val_loss: 0.4121 - val_accuracy: 0.8865
# Epoch 5/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.4102 - accuracy: 0.8753 - val_loss: 0.4053 - val_accuracy: 0.8851
# Epoch 6/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.4104 - accuracy: 0.8734 - val_loss: 0.4184 - val_accuracy: 0.8810
# Epoch 7/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.3517 - accuracy: 0.8933 - val_loss: 0.4366 - val_accuracy: 0.8769
# Epoch 8/40
# 81/81 [==============================] - 16s 185ms/step - loss: 0.3619 - accuracy: 0.8890 - val_loss: 0.4207 - val_accuracy: 0.8796
# Epoch 9/40
# 81/81 [==============================] - 16s 187ms/step - loss: 0.3327 - accuracy: 0.9026 - val_loss: 0.4118 - val_accuracy: 0.8837
# Epoch 10/40
# 81/81 [==============================] - 15s 185ms/step - loss: 0.3236 - accuracy: 0.8933 - val_loss: 0.4255 - val_accuracy: 0.8865
# 12/12 [==============================] - 2s 134ms/step - loss: 0.3131 - accuracy: 0.9032

# %%
evaluate_test
# Out:
# [[1.2312562465667725, 0.8413978219032288],
#  [0.7921797037124634, 0.8790322542190552],
#  [0.6224293112754822, 0.897849440574646],
#  [0.31313613057136536, 0.9032257795333862]]

# %%
import pandas as pd


table_data = {'Regularizer': reg_values, 'Loss Diff Mean': [], 'Accuracy Diff Mean': []}

for i, history in enumerate(histories_Adam_reg):
    reg = reg_values[i]

    train_loss_diff = np.abs(np.array(history.history['loss']) - np.array(history.history['val_loss']))
    avg_loss_diff = np.mean(train_loss_diff)


    train_acc_diff = np.abs(np.array(history.history['accuracy']) - np.array(history.history['val_accuracy']))
    avg_acc_diff = np.mean(train_acc_diff)


    # Aggiunta dei valori nella tabella
    table_data['Accuracy Diff Mean'].append(avg_acc_diff)
    table_data['Loss Diff Mean'].append(avg_loss_diff)

    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.ylim([0, 2.0])
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['train', 'valid'])
    plt.title(f'Training and Validation Loss (regularizer = {reg})');


    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.ylim([0.5, 1.0])
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['train', 'valid'])
    plt.title(f'Training and Validation Accuracy (regularizer = {reg})');

    plt.tight_layout()
    plt.show()


table_df = pd.DataFrame(table_data)


print(table_df.to_string(index=False, float_format='%.4f'))
# Out:
#  Regularizer  Loss Diff Mean  Accuracy Diff Mean
#       0.1000          0.7392              0.0411
#       0.0100          0.1462              0.0185
#       0.0010          0.1263              0.0343
#       0.0001          0.0919              0.0359

# %% [markdown]
# # Net with optimizer RMSprop and variable regularizer
# - dense: 512
# - learning rate: 0.001

# %%
# values of regularizer
reg_values = [0.1, 0.01, 0.001, 0.0001]


histories_RMS_reg = []
evaluate_test = []

for reg in reg_values:
    # Create the model
    vgg_model = keras.applications.VGG16(input_shape=(224,224,3), weights='imagenet', include_top=False)


    for layer in vgg_model.layers:
        layer.trainable = False

    from keras import regularizers

    inputs = keras.Input(shape=(224, 224, 3))
    x = inputs
    x = data_augmentation(x)
    x = keras.applications.vgg16.preprocess_input(x)
    x = vgg_model(x)
    x = keras.layers.GlobalAveragePooling2D()(x)


    x = keras.layers.BatchNormalization()(x)

    x = keras.layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(reg))(x)
    x = keras.layers.Dropout(0.5)(x)
    x = keras.layers.BatchNormalization()(x)
    outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
    net_RMS_reg = keras.Model(inputs=inputs, outputs=outputs)


    # Compile the model
    net_RMS_reg.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.RMSprop(learning_rate=0.001),
              metrics=['accuracy'])

    net_RMS_reg.summary()

    callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

    # train the model
    history_RMS_reg = net_RMS_reg.fit(train_dataset,
          epochs=40,
          validation_data=val_dataset,
          callbacks=[callback])

    evaluate = loss, accuracy = net_RMS_reg.evaluate(test_dataset)
    evaluate_test.append(evaluate)

    net_RMS_reg.save('drive/MyDrive/FDL/Vgg_RMS_reg_{}.h5'.format(reg))

    histories_RMS_reg.append(history_RMS_reg)
# Out:
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_22 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem_10  (None, 224, 224, 3)      0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_10 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d_10  (None, 512)              0
#   (GlobalAveragePooling2D)
#
#  batch_normalization_20 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_20 (Dense)            (None, 512)               262656
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  batch_normalization_21 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_21 (Dense)            (None, 5)                 2565
#
# =================================================================
# Total params: 14,984,005
# Trainable params: 267,269
# Non-trainable params: 14,716,736
# _________________________________________________________________
# Epoch 1/40
# 81/81 [==============================] - 18s 185ms/step - loss: 18.3580 - accuracy: 0.6825 - val_loss: 5.4623 - val_accuracy: 0.8085
# Epoch 2/40
# 81/81 [==============================] - 16s 192ms/step - loss: 3.2635 - accuracy: 0.7834 - val_loss: 1.9739 - val_accuracy: 0.8030
# Epoch 3/40
# 81/81 [==============================] - 16s 186ms/step - loss: 1.7378 - accuracy: 0.7881 - val_loss: 1.4658 - val_accuracy: 0.8427
# Epoch 4/40
# 81/81 [==============================] - 16s 189ms/step - loss: 1.4739 - accuracy: 0.7900 - val_loss: 1.3731 - val_accuracy: 0.8304
# Epoch 5/40
# 81/81 [==============================] - 15s 185ms/step - loss: 1.3687 - accuracy: 0.8033 - val_loss: 1.3785 - val_accuracy: 0.8153
# Epoch 6/40
# 81/81 [==============================] - 15s 183ms/step - loss: 1.3986 - accuracy: 0.7850 - val_loss: 1.3338 - val_accuracy: 0.8427
# Epoch 7/40
# 81/81 [==============================] - 15s 184ms/step - loss: 1.3312 - accuracy: 0.7951 - val_loss: 1.3012 - val_accuracy: 0.8440
# Epoch 8/40
# 81/81 [==============================] - 15s 184ms/step - loss: 1.2913 - accuracy: 0.7947 - val_loss: 1.3198 - val_accuracy: 0.8331
# Epoch 9/40
# 81/81 [==============================] - 16s 187ms/step - loss: 1.2830 - accuracy: 0.8044 - val_loss: 1.3022 - val_accuracy: 0.8276
# Epoch 10/40
# 81/81 [==============================] - 16s 191ms/step - loss: 1.2843 - accuracy: 0.8002 - val_loss: 1.2480 - val_accuracy: 0.8304
# Epoch 11/40
# 81/81 [==============================] - 15s 185ms/step - loss: 1.2129 - accuracy: 0.8157 - val_loss: 1.2318 - val_accuracy: 0.8427
# Epoch 12/40
# 81/81 [==============================] - 15s 183ms/step - loss: 1.2600 - accuracy: 0.7998 - val_loss: 1.2165 - val_accuracy: 0.8372
# Epoch 13/40
# 81/81 [==============================] - 15s 182ms/step - loss: 1.2045 - accuracy: 0.8118 - val_loss: 1.1632 - val_accuracy: 0.8482
# Epoch 14/40
# 81/81 [==============================] - 15s 184ms/step - loss: 1.2238 - accuracy: 0.8099 - val_loss: 1.4035 - val_accuracy: 0.8044
# Epoch 15/40
# 81/81 [==============================] - 15s 184ms/step - loss: 1.1718 - accuracy: 0.8150 - val_loss: 1.1854 - val_accuracy: 0.8249
# Epoch 16/40
# 81/81 [==============================] - 15s 183ms/step - loss: 1.1829 - accuracy: 0.8126 - val_loss: 1.1423 - val_accuracy: 0.8468
# Epoch 17/40
# 81/81 [==============================] - 17s 204ms/step - loss: 1.1974 - accuracy: 0.7978 - val_loss: 1.2122 - val_accuracy: 0.8427
# Epoch 18/40
# 81/81 [==============================] - 15s 183ms/step - loss: 1.1772 - accuracy: 0.7994 - val_loss: 1.1192 - val_accuracy: 0.8440
# Epoch 19/40
# 81/81 [==============================] - 16s 185ms/step - loss: 1.1476 - accuracy: 0.8185 - val_loss: 1.2216 - val_accuracy: 0.8345
# Epoch 20/40
# 81/81 [==============================] - 17s 205ms/step - loss: 1.1308 - accuracy: 0.8173 - val_loss: 1.0957 - val_accuracy: 0.8482
# Epoch 21/40
# 81/81 [==============================] - 15s 184ms/step - loss: 1
40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.4843 - accuracy: 0.8418 - val_loss: 0.4810 - val_accuracy: 0.8646
# Epoch 4/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.4561 - accuracy: 0.8555 - val_loss: 0.4701 - val_accuracy: 0.8782
# Epoch 5/40
# 81/81 [==============================] - 15s 184ms/step - loss: 0.4030 - accuracy: 0.8781 - val_loss: 0.4582 - val_accuracy: 0.8728
# Epoch 6/40
# 81/81 [==============================] - 17s 205ms/step - loss: 0.3955 - accuracy: 0.8773 - val_loss: 0.4464 - val_accuracy: 0.8755
# Epoch 7/40
# 81/81 [==============================] - 16s 188ms/step - loss: 0.3687 - accuracy: 0.8827 - val_loss: 0.4439 - val_accuracy: 0.8837
# Epoch 8/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.3395 - accuracy: 0.9018 - val_loss: 0.4689 - val_accuracy: 0.8714
# Epoch 9/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.3521 - accuracy: 0.8913 - val_loss: 0.4493 - val_accuracy: 0.8851
# Epoch 10/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.3264 - accuracy: 0.9026 - val_loss: 0.4739 - val_accuracy: 0.8782
# Epoch 11/40
# 81/81 [==============================] - 16s 187ms/step - loss: 0.3152 - accuracy: 0.9088 - val_loss: 0.5054 - val_accuracy: 0.8659
# Epoch 12/40
# 81/81 [==============================] - 16s 191ms/step - loss: 0.3061 - accuracy: 0.9147 - val_loss: 0.4759 - val_accuracy: 0.8837
# 12/12 [==============================] - 2s 134ms/step - loss: 0.3642 - accuracy: 0.8952

# %%
evaluate_test
# Out:
# [[0.9911829829216003, 0.8629032373428345],
#  [0.6919575929641724, 0.8682795763015747],
#  [0.532736599445343, 0.9005376100540161],
#  [0.3642004728317261, 0.8951612710952759]]

# %%
import pandas as pd


table_data = {'Regularizer': reg_values, 'Loss Diff Mean': [], 'Accuracy Diff Mean': []}

for i, history in enumerate(histories_RMS_reg):
    reg = reg_values[i]

    train_loss_diff = np.abs(np.array(history.history['loss']) - np.array(history.history['val_loss']))
    avg_loss_diff = np.mean(train_loss_diff)

    train_acc_diff = np.abs(np.array(history.history['accuracy']) - np.array(history.history['val_accuracy']))
    avg_acc_diff = np.mean(train_acc_diff)


    table_data['Accuracy Diff Mean'].append(avg_acc_diff)
    table_data['Loss Diff Mean'].append(avg_loss_diff)

    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.ylim([0, 2.0])
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['train', 'valid' ])
    plt.title(f'Training and Validation Loss (regularizer = {reg})');


    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.ylim([0.5, 1.0])
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['train', 'valid'])
    plt.title(f'Training and Validation Accuracy (regularizer = {reg})');

    plt.tight_layout()
    plt.show()


table_df = pd.DataFrame(table_data)


print(table_df.to_string(index=False, float_format='%.4f'))
# Out:
#  Regularizer  Loss Diff Mean  Accuracy Diff Mean
#       0.1000          0.6159              0.0364
#       0.0100          0.1934              0.0208
#       0.0010          0.1672              0.0342
#       0.0001          0.1213              0.0325

# %% [markdown]
# # Adam vs RMSprop graphs with different regularizer values

# %%
plt.figure(figsize=(12, 10))

plt.subplot(2, 2, 1)

for i, history in enumerate(histories_Adam_reg):
    plt.plot(history.history['val_loss'], label='regularizer {}'.format(reg_values[i]))
plt.ylim([0, 2.0])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Loss (Adam)')
plt.legend()



plt.subplot(2, 2, 2)
for i, history in enumerate(histories_RMS_reg):
    plt.plot(history.history['val_loss'], label='regularizer {}'.format(reg_values[i]))
plt.ylim([0, 2.0])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Loss (RMS)')
plt.legend()



plt.subplot(2, 2, 3)
for i, history in enumerate(histories_Adam_reg):
    plt.plot(history.history['val_accuracy'], label='regularizer {}'.format(reg_values[i]))
plt.ylim([0.5, 1.0])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Accuracy (Adam)')
plt.legend()



plt.subplot(2, 2, 4)
for i, history in enumerate(histories_RMS_reg):
    plt.plot(history.history['val_accuracy'], label='regularizer {}'.format(reg_values[i]))
plt.ylim([0.5, 1.0])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Accuracy (RMS)')
plt.legend()

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(histories_Adam_reg[3].history['val_loss'], label='Adam, regularizer {}'.format(reg_values[3]))
plt.plot(histories_RMS_reg[3].history['val_loss'], label='RMS, regularizer {}'.format(reg_values[3]))
plt.ylim([0, 2.0])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Loss Adam vs RMSprop')
plt.legend()



plt.subplot(1, 2, 2)
plt.plot(histories_Adam_reg[3].history['val_accuracy'], label='Adam, regularizer {}'.format(reg_values[3]))
plt.plot(histories_RMS_reg[3].history['val_accuracy'], label='RMS, regularizer {}'.format(reg_values[3]))
plt.ylim([0.5, 1.0])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Accuracy Adam vs RMSprop')
plt.legend()

# %% [markdown]
# For the following model we fix regularizer=0.0001 for both Adam and RMSprop optimizers

# %% [markdown]
# # Net with optimizer Adam and variable number of dense nodes
# - learning rate: 0.001
# - regularizer: 0.0001

# %%
# number of dense nodes
num_dense = [64, 128, 512]


histories_Adam_dense = []
evaluate_test = []

for dense in num_dense:
    # Create the model
    vgg_model = keras.applications.VGG16(input_shape=(224,224,3), weights='imagenet', include_top=False)


    for layer in vgg_model.layers:
        layer.trainable = False

    from keras import regularizers

    inputs = keras.Input(shape=(224, 224, 3))
    x = inputs
    x = data_augmentation(x)
    x = keras.applications.vgg16.preprocess_input(x)
    x = vgg_model(x)
    x = keras.layers.GlobalAveragePooling2D()(x)


    x = keras.layers.BatchNormalization()(x)

    x = keras.layers.Dense(dense, activation='relu', kernel_regularizer=regularizers.l2(0.0001))(x)
    x = keras.layers.Dropout(0.5)(x)
    x = keras.layers.BatchNormalization()(x)
    outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
    net_Adam_dense = keras.Model(inputs=inputs, outputs=outputs)

    from tensorflow.keras.optimizers import Adam
    # Compile the model
    net_Adam_dense.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy'])

    net_Adam_dense.summary()

    callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

    # train the model
    history_Adam_dense = net_Adam_dense.fit(train_dataset,
          epochs=40,
          validation_data=val_dataset,
          callbacks=[callback])

    loss, accuracy = net_Adam_dense.evaluate(test_dataset)
    evaluate_test.append(evaluate)

    net_Adam_dense.save('drive/MyDrive/FDL/Vgg_Adam_dense_{}.h5'.format(dense))

    histories_Adam_dense.append(history_Adam_dense)
# Out:
# Model: "model_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_30 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem_14  (None, 224, 224, 3)      0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_14 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d_14  (None, 512)              0
#   (GlobalAveragePooling2D)
#
#  batch_normalization_28 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_28 (Dense)            (None, 64)                32832
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  batch_normalization_29 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_29 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 14,750,149
# Trainable params: 34,309
# Non-trainable params: 14,715,840
# _________________________________________________________________
# Epoch 1/40
# 81/81 [==============================] - 17s 180ms/step - loss: 1.2751 - accuracy: 0.5181 - val_loss: 0.6368 - val_accuracy: 0.7934
# Epoch 2/40
# 81/81 [==============================] - 17s 200ms/step - loss: 0.7991 - accuracy: 0.7168 - val_loss: 0.5191 - val_accuracy: 0.8290
# Epoch 3/40
# 81/81 [==============================] - 16s 187ms/step - loss: 0.6731 - accuracy: 0.7596 - val_loss: 0.4750 - val_accuracy: 0.8399
# Epoch 4/40
# 81/81 [==============================] - 16s 187ms/step - loss: 0.6147 - accuracy: 0.7861 - val_loss: 0.4561 - val_accuracy: 0.8482
# Epoch 5/40
# 81/81 [==============================] - 15s 184ms/step - loss: 0.5575 - accuracy: 0.7998 - val_loss: 0.4307 - val_accuracy: 0.8468
# Epoch 6/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.5166 - accuracy: 0.8122 - val_loss: 0.4196 - val_accuracy: 0.8495
# Epoch 7/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.5014 - accuracy: 0.8294 - val_loss: 0.3974 - val_accuracy: 0.8591
# Epoch 8/40
# 81/81 [==============================] - 16s 187ms/step - loss: 0.4590 - accuracy: 0.8298 - val_loss: 0.3831 - val_accuracy: 0.8605
# Epoch 9/40
# 81/81 [==============================] - 16s 187ms/step - loss: 0.4477 - accuracy: 0.8442 - val_loss: 0.3793 - val_accuracy: 0.8646
# Epoch 10/40
# 81/81 [==============================] - 15s 184ms/step - loss: 0.4563 - accuracy: 0.8348 - val_loss: 0.3796 - val_accuracy: 0.8700
# Epoch 11/40
# 81/81 [==============================] - 17s 205ms/step - loss: 0.4288 - accuracy: 0.8559 - val_loss: 0.3717 - val_accuracy: 0.8769
# Epoch 12/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.4066 - accuracy: 0.8543 - val_loss: 0.3657 - val_accuracy: 0.8865
# Epoch 13/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.4080 - accuracy: 0.8601 - val_loss: 0.3673 - val_accuracy: 0.8837
# Epoch 14/40
# 81/81 [==============================] - 17s 205ms/step - loss: 0.3905 - accuracy: 0.8563 - val_loss: 0.3693 - val_accuracy: 0.8769
# Epoch 15/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.3752 - accuracy: 0.8668 - val_loss: 0.3612 - val_accuracy: 0.8837
# Epoch 16/40
# 81/81 [==============================] - 16s 182ms/step - loss: 0.3939 - accuracy: 0.8605 - val_loss: 0.3684 - val_accuracy: 0.8755
# Epoch 17/40
# 81/81 [==============================] - 16s 190ms/step - loss: 0.3855 - accuracy: 0.8609 - val_loss: 0.3629 - val_accuracy: 0.8769
# Epoch 18/40
# 81/81 [==============================] - 16s 187ms/step - loss: 0.3766 - accuracy: 0.8722 - val_loss: 0.3502 - val_accuracy: 0.8769
# Epoch 19/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.3613 - accuracy: 0.8746 - val_loss: 0.3614 - val_accuracy: 0.8796
# Epoch 20/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.3499 - accuracy: 0.8816 - val_loss: 0.3543 - val_accuracy: 0.8837
# Epoch 21/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.3177 - accuracy: 0.8948 - val_loss: 0.3728 - val_accuracy: 0.8782
# Epoch 22/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.3477 - accuracy: 0.8851 - val_loss: 0.3629 - val_accuracy: 0.8837
# Epoch 23/40
# 81/81 [==============================] - 15s 184ms/step - loss: 0.3227 - accuracy: 0.8874 - val_loss: 0.3707 - val_accuracy: 0.8769
# 12/12 [==============================] - 2s 135ms/step - loss: 0.2831 - accuracy: 0.8978
# Model: "model_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_32 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem_15  (None, 224, 224, 3)      0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_15 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d_15  (None, 512)              0
#   (GlobalAveragePooling2D)
#
#  batch_normalization_30 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_30 (Dense)            (None, 128)               65664
#
#  dropout_15 (Dropout)        (None, 128)               0
#
#  batch_normalization_31 (Bat  (None, 128)              512
#  chNormalization)
#
#  dense_31 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 14,783,557
# Trainable params: 67,589
# Non-trainable params: 14,715,968
# _________________________________________________________________
# Epoch 1/40
# 81/81 [==============================] - 18s 185ms/step - loss: 1.1308 - accuracy: 0.5894 - val_loss: 0.6224 - val_accuracy: 0.8044
# Epoch 2/40
# 81/81 [==============================] - 15s 184ms/step - loss: 0.6987 - accuracy: 0.7491 - val_loss: 0.5229 - val_accuracy: 0.8331
# Epoch 3/40
# 81/81 [==============================] - 16s 187ms/step - loss: 0.5904 - accuracy: 0.7935 - val_loss: 0.4467 - val_accuracy: 0.8482
# Epoch 4/40
# 81/81 [==============================] - 15s 184ms/step - loss: 0.5198 - accuracy: 0.8115 - val_loss: 0.4357 - val_accuracy: 0.8564
# Epoch 5/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.4943 - accuracy: 0.8282 - val_loss: 0.4352 - val_accuracy: 0.8659
# Epoch 6/40
# 81/81 [==============================] - 17s 203ms/step - loss: 0.4637 - accuracy: 0.8329 - val_loss: 0.4241 - val_accuracy: 0.8591
# Epoch 7/40
# 81/81 [==============================] - 16s 188ms/step - loss: 0.4408 - accuracy: 0.8473 - val_loss: 0.4087 - val_accuracy: 0.8700
# Epoch 8/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.4301 - accuracy: 0.8481 - val_loss: 0.4036 - val_accuracy: 0.8673
# Epoch 9/40
# 81/81 [==============================] - 17s 202ms/step - loss: 0.3997 - accuracy: 0.8648 - val_loss: 0.3982 - val_accuracy: 0.8728
# Epoch 10/40
# 81/81 [==============================] - 15s 184ms/step - loss: 0.4047 - accuracy: 0.8547 - val_loss: 0.4038 - val_accuracy: 0.8741
# Epoch 11/40
# 81/81 [==============================] - 15s 185ms/step - loss: 0.3722 - accuracy: 0.8652 - val_loss: 0.3960 - val_accuracy: 0.8796
# Epoch 12/40
# 81/81 [==============================] - 16s 187ms/step - loss: 0.3742 - accuracy: 0.8726 - val_loss: 0.3942 - val_accuracy: 0.8755
# Epoch 13/40
# 81/81 [==============================] - 16s 188ms/step - loss: 0.3469 - accuracy: 0.8785 - val_loss: 0.3677 - val_accuracy: 0.8878
# Epoch 14/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.3487 - accuracy: 0.8870 - val_loss: 0.3673 - val_accuracy: 0.8851
# Epoch 15/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.3160 - accuracy: 0.8917 - val_loss: 0.3790 - val_accuracy: 0.8824
# Epoch 16/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.3082 - accuracy: 0.8972 - val_loss: 0.3867 - val_accuracy: 0.8837
# Epoch 17/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.3331 - accuracy: 0.8862 - val_loss: 0.3841 - val_accuracy: 0.8782
# Epoch 18/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.3121 - accuracy: 0.8987 - val_loss: 0.3881 - val_accuracy: 0.8796
# Epoch 19/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.3086 - accuracy: 0.8948 - val_loss: 0.3939 - val_accuracy: 0.8796
# 12/12 [==============================] - 3s 136ms/step - loss: 0.3246 - accuracy: 0.8925
# Model: "model_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_34 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem_16  (None, 224, 224, 3)      0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_16 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d_16  (None, 512)              0
#   (GlobalAveragePooling2D)
#
#  batch_normalization_32 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_32 (Dense)            (None, 512)               262656
#
#  dropout_16 (Dropout)        (None, 512)               0
#
#  batch_normalization_33 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_33 (Dense)            (None, 5)                 2565
#
# =================================================================
# Total params: 14,984,005
# Trainable params: 267,269
# Non-trainable params: 14,716,736
# _________________________________________________________________
# Epoch 1/40
# 81/81 [==============================] - 18s 187ms/step - loss: 0.9572 - accuracy: 0.6778 - val_loss: 0.5823 - val_accuracy: 0.8440
# Epoch 2/40
# 81/81 [==============================] - 15s 184ms/step - loss: 0.5870 - accuracy: 0.8076 - val_loss: 0.4829 - val_accuracy: 0.8618
# Epoch 3/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.5090 - accuracy: 0.8395 - val_loss: 0.4637 - val_accuracy: 0.8632
# Epoch 4/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.4385 - accuracy: 0.8535 - val_loss: 0.4690 - val_accuracy: 0.8646
# Epoch 5/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.4386 - accuracy: 0.8617 - val_loss: 0.4726 - val_accuracy: 0.8769
# Epoch 6/40
# 81/81 [==============================] - 15s 183ms/step - loss: 0.3780 - accuracy: 0.8804 - val_loss: 0.4669 - val_accuracy: 0.8769
# Epoch 7/40
# 81/81 [==============================] - 17s 203ms/step - loss: 0.3760 - accuracy: 0.8851 - val_loss: 0.4521 - val_accuracy: 0.8673
# Epoch 8/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.3510 - accuracy: 0.8886 - val_loss: 0.4789 - val_accuracy: 0.8659
# Epoch 9/40
# 81/81 [==============================] - 15s 186ms/step - loss: 0.3442 - accuracy: 0.9014 - val_loss: 0.4408 - val_accuracy: 0.8810
# Epoch 10/40
# 81/81 [==============================] - 16s 188ms/step - loss: 0.3182 - accuracy: 0.9065 - val_loss: 0.4502 - val_accuracy: 0.8796
# Epoch 11/40
# 81/81 [==============================] - 15s 185ms/step - loss: 0.3076 - accuracy: 0.9081 - val_loss: 0.4631 - val_accuracy: 0.8741
# Epoch 12/40
# 81/81 [==============================] - 16s 187ms/step - loss: 0.3185 - accuracy: 0.9053 - val_loss: 0.4672 - val_accuracy: 0.8755
# Epoch 13/40
# 81/81 [==============================] - 15s 184ms/step - loss: 0.3185 - accuracy: 0.9030 - val_loss: 0.4770 - val_accuracy: 0.8687
# Epoch 14/40
# 81/81 [==============================] - 16s 187ms/step - loss: 0.3012 - accuracy: 0.9088 - val_loss: 0.4553 - val_accuracy: 0.8755
# 12/12 [==============================] - 2s 132ms/step - loss: 0.3019 - accuracy: 0.9086

# %%
evaluate_test
# Out:
# [[0.3642004728317261, 0.8951612710952759],
#  [0.3642004728317261, 0.8951612710952759],
#  [0.3642004728317261, 0.8951612710952759]]

# %%
import pandas as pd


table_data = {'Dense': num_dense, 'Loss Diff Mean': [], 'Accuracy Diff Mean': []}

for i, history in enumerate(histories_Adam_dense):
    dense = num_dense[i]

    train_loss_diff = np.abs(np.array(history.history['loss']) - np.array(history.history['val_loss']))
    avg_loss_diff = np.mean(train_loss_diff)

    train_acc_diff = np.abs(np.array(history.history['accuracy']) - np.array(history.history['val_accuracy']))
    avg_acc_diff = np.mean(train_acc_diff)


    table_data['Accuracy Diff Mean'].append(avg_acc_diff)
    table_data['Loss Diff Mean'].append(avg_loss_diff)

    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.ylim([0, 2.0])
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['train', 'valid' ])
    plt.title(f'Training and Validation Loss (dense = {dense})');


    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.ylim([0.5, 1.0])
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['train', 'valid'])
    plt.title(f'Training and Validation Accuracy (dense = {dense})');

    plt.tight_layout()
    plt.show()


table_df = pd.DataFrame(table_data)


print(table_df.to_string(index=False, float_format='%.4f'))
# Out:
#  Dense  Loss Diff Mean  Accuracy Diff Mean
#     64          0.0954              0.0398
#    128          0.0794              0.0329
#    512          0.1233              0.0352

# %% [markdown]
# # Net with optimizer RMSprop and variable number of dense nodes
# - learning rate: 0.001
# - regularizer: 0.0001

# %%
# number of dense nodes
num_dense = [64, 128, 512]


histories_RMS_dense = []
evaluate_test = []

for dense in num_dense:
    # Create the model
    vgg_model = keras.applications.VGG16(input_shape=(224,224,3), weights='imagenet', include_top=False)


    for layer in vgg_model.layers:
        layer.trainable = False

    from keras import regularizers

    inputs = keras.Input(shape=(224, 224, 3))
    x = inputs
    x = data_augmentation(x)
    x = keras.applications.vgg16.preprocess_input(x)
    x = vgg_model(x)
    x = keras.layers.GlobalAveragePooling2D()(x)


    x = keras.layers.BatchNormalization()(x)

    x = keras.layers.Dense(dense, activation='relu', kernel_regularizer=regularizers.l2(0.0001))(x)
    x = keras.layers.Dropout(0.5)(x)
    x = keras.layers.BatchNormalization()(x)
    outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
    net_RMS_dense = keras.Model(inputs=inputs, outputs=outputs)


    # Compile the model
    net_RMS_dense.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.RMSprop(learning_rate=0.001),
              metrics=['accuracy'])

    net_RMS_dense.summary()

    callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

    # train the model
    history_RMS_dense = net_RMS_dense.fit(train_dataset,
          epochs=40,
          validation_data=val_dataset,
          callbacks=[callback])

    evaluate = loss, accuracy = net_RMS_dense.evaluate(test_dataset)
    evaluate_test.append(evaluate)

    net_RMS_dense.save('drive/MyDrive/FDL/Vgg_RMS_dense_{}.h5'.format(dense))

    histories_RMS_dense.append(history_RMS_dense)
# Out:
# Model: "model_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input
40
# 81/81 [==============================] - 15s 184ms/step - loss: 0.5823 - accuracy: 0.7924 - val_loss: 0.4838 - val_accuracy: 0.8468
# Epoch 4/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.5177 - accuracy: 0.8208 - val_loss: 0.4479 - val_accuracy: 0.8523
# Epoch 5/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.4670 - accuracy: 0.8407 - val_loss: 0.4431 - val_accuracy: 0.8577
# Epoch 6/40
# 81/81 [==============================] - 17s 202ms/step - loss: 0.4423 - accuracy: 0.8379 - val_loss: 0.4308 - val_accuracy: 0.8673
# Epoch 7/40
# 81/81 [==============================] - 16s 186ms/step - loss: 0.4082 - accuracy: 0.8578 - val_loss: 0.4402 - val_accuracy: 0.8687
# Epoch 8/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.3850 - accuracy: 0.8761 - val_loss: 0.4096 - val_accuracy: 0.8632
# Epoch 9/40
# 81/81 [==============================] - 16s 183ms/step - loss: 0.3761 - accuracy: 0.8656 - val_loss: 0.4116 - val_accuracy: 0.8728
# Epoch 10/40
# 81/81 [==============================] - 15s 184ms/step - loss: 0.3657 - accuracy: 0.8753 - val_loss: 0.4167 - val_accuracy: 0.8728
# Epoch 11/40
# 81/81 [==============================] - 15s 178ms/step - loss: 0.3666 - accuracy: 0.8726 - val_loss: 0.4202 - val_accuracy: 0.8714
# Epoch 12/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.3362 - accuracy: 0.8847 - val_loss: 0.4226 - val_accuracy: 0.8714
# Epoch 13/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.3517 - accuracy: 0.8773 - val_loss: 0.4273 - val_accuracy: 0.8714
# 12/12 [==============================] - 2s 133ms/step - loss: 0.3105 - accuracy: 0.8952
# Model: "model_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_40 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem_19  (None, 224, 224, 3)      0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_19 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d_19  (None, 512)              0
#   (GlobalAveragePooling2D)
#
#  batch_normalization_38 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_38 (Dense)            (None, 512)               262656
#
#  dropout_19 (Dropout)        (None, 512)               0
#
#  batch_normalization_39 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_39 (Dense)            (None, 5)                 2565
#
# =================================================================
# Total params: 14,984,005
# Trainable params: 267,269
# Non-trainable params: 14,716,736
# _________________________________________________________________
# Epoch 1/40
# 81/81 [==============================] - 17s 184ms/step - loss: 0.9057 - accuracy: 0.6989 - val_loss: 0.5709 - val_accuracy: 0.8345
# Epoch 2/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.5475 - accuracy: 0.8278 - val_loss: 0.5265 - val_accuracy: 0.8591
# Epoch 3/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.4811 - accuracy: 0.8496 - val_loss: 0.4711 - val_accuracy: 0.8659
# Epoch 4/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.4374 - accuracy: 0.8563 - val_loss: 0.4395 - val_accuracy: 0.8824
# Epoch 5/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.3899 - accuracy: 0.8757 - val_loss: 0.4267 - val_accuracy: 0.8741
# Epoch 6/40
# 81/81 [==============================] - 15s 180ms/step - loss: 0.3884 - accuracy: 0.8773 - val_loss: 0.4486 - val_accuracy: 0.8700
# Epoch 7/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.3780 - accuracy: 0.8804 - val_loss: 0.5077 - val_accuracy: 0.8673
# Epoch 8/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.3466 - accuracy: 0.8921 - val_loss: 0.5225 - val_accuracy: 0.8700
# Epoch 9/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.3353 - accuracy: 0.8948 - val_loss: 0.5092 - val_accuracy: 0.8741
# Epoch 10/40
# 81/81 [==============================] - 15s 182ms/step - loss: 0.3162 - accuracy: 0.9034 - val_loss: 0.4427 - val_accuracy: 0.8865
# 12/12 [==============================] - 2s 131ms/step - loss: 0.3557 - accuracy: 0.9032

# %%
evaluate_test
# Out:
# [[0.2972753047943115, 0.9032257795333862],
#  [0.3105255961418152, 0.8951612710952759],
#  [0.35567396879196167, 0.9032257795333862]]

# %%
import pandas as pd


table_data = {'Dense': num_dense, 'Loss Diff Mean': [], 'Accuracy Diff Mean': []}

for i, history in enumerate(histories_RMS_dense):
    dense = num_dense[i]

    train_loss_diff = np.abs(np.array(history.history['loss']) - np.array(history.history['val_loss']))
    avg_loss_diff = np.mean(train_loss_diff)
    avg_loss_diff_text = f'Loss Diff: {avg_loss_diff:.4f}'

    train_acc_diff = np.abs(np.array(history.history['accuracy']) - np.array(history.history['val_accuracy']))
    avg_acc_diff = np.mean(train_acc_diff)
    avg_acc_diff_text = f'Accuracy Diff: {avg_acc_diff:.4f}'


    table_data['Accuracy Diff Mean'].append(avg_acc_diff)
    table_data['Loss Diff Mean'].append(avg_loss_diff)

    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.ylim([0, 2.0])
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['train', 'valid'])
    plt.title(f'Training and Validation Loss (number of dense = {dense})');


    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.ylim([0.5, 1.0])
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['train', 'valid'])
    plt.title(f'Training and Validation Accuracy (number of dense = {dense})');

    plt.tight_layout()
    plt.show()


table_df = pd.DataFrame(table_data)


print(table_df.to_string(index=False, float_format='%.4f'))
# Out:
#  Dense  Loss Diff Mean  Accuracy Diff Mean
#     64          0.0879              0.0340
#    128          0.0867              0.0350
#    512          0.1071              0.0291

# %% [markdown]
# # Adam vs RMSprop graphs with different number of dense nodes

# %%
plt.figure(figsize=(12, 10))

plt.subplot(2, 2, 1)

for i, history in enumerate(histories_Adam_dense):
    plt.plot(history.history['val_loss'], label='dense {}'.format(num_dense[i]))
plt.ylim([0, 2.0])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Loss (Adam)')
plt.legend()



plt.subplot(2, 2, 2)
for i, history in enumerate(histories_RMS_dense):
    plt.plot(history.history['val_loss'], label='dense {}'.format(num_dense[i]))
plt.ylim([0, 2.0])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Loss (RMS)')
plt.legend()



plt.subplot(2, 2, 3)
for i, history in enumerate(histories_Adam_dense):
    plt.plot(history.history['val_accuracy'], label='dense {}'.format(num_dense[i]))
plt.ylim([0.5, 1.0])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Accuracy (Adam)')
plt.legend()



plt.subplot(2, 2, 4)
for i, history in enumerate(histories_RMS_dense):
    plt.plot(history.history['val_accuracy'], label='dense {}'.format(num_dense[i]))
plt.ylim([0.5, 1.0])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Accuracy (RMS)')
plt.legend()

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(histories_Adam_dense[1].history['val_loss'], label='Adam, dense {}'.format(num_dense[1]))
plt.plot(histories_RMS_dense[1].history['val_loss'], label='RMS, dense {}'.format(num_dense[1]))
plt.ylim([0, 2.0])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Loss Adam vs RMSprop')
plt.legend()



plt.subplot(1, 2, 2)
plt.plot(histories_Adam_dense[1].history['val_accuracy'], label='Adam, dense {}'.format(num_dense[1]))
plt.plot(histories_RMS_dense[1].history['val_accuracy'], label='RMS, dense {}'.format(num_dense[1]))
plt.ylim([0.5, 1.0])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Validation Accuracy Adam vs RMSprop')
plt.legend()

# %% [markdown]
# Now we can fix the number of dense = 128 for both RMSprop and Adam optimizer.

# %% [markdown]
# # Net with optimizer Adam and different augmentation
# - lr: 0.001
# - dense: 128
# - regularizer: 0.0001

# %%
def random_channel_flip(image):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    return image

new_data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomTranslation(0.1, 0.1),
        layers.RandomContrast(0.2),
        layers.RandomBrightness(0.2),
        layers.GaussianNoise(0.1),
        layers.Lambda(random_channel_flip),
    ]
)





vgg_model = keras.applications.VGG16(input_shape=(224,224,3), weights='imagenet', include_top=False)


for layer in vgg_model.layers:
    layer.trainable = False

from keras import regularizers

inputs = keras.Input(shape=(224, 224, 3))
x = inputs
x = new_data_augmentation(x)
x = keras.applications.vgg16.preprocess_input(x)
x = vgg_model(x)

x = keras.layers.GlobalAveragePooling2D()(x)


x = keras.layers.BatchNormalization()(x)

x = keras.layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.0001))(x)
x = keras.layers.Dropout(0.5)(x)

outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
net_Adam_na = keras.Model(inputs=inputs, outputs=outputs)


from tensorflow.keras.optimizers import Adam
# Compile the model
net_Adam_na.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy
40
# 81/81 [==============================] - 15s 186ms/step - loss: 0.3299 - accuracy: 0.8839 - val_loss: 0.3689 - val_accuracy: 0.8837
# Epoch 24/40
# 81/81 [==============================] - 15s 185ms/step - loss: 0.3171 - accuracy: 0.8909 - val_loss: 0.3898 - val_accuracy: 0.8947
# Epoch 25/40
# 81/81 [==============================] - 15s 185ms/step - loss: 0.3326 - accuracy: 0.8862 - val_loss: 0.3742 - val_accuracy: 0.8974
# Epoch 26/40
# 81/81 [==============================] - 15s 186ms/step - loss: 0.3180 - accuracy: 0.8909 - val_loss: 0.3795 - val_accuracy: 0.8878
# Epoch 27/40
# 81/81 [==============================] - 15s 185ms/step - loss: 0.3583 - accuracy: 0.8851 - val_loss: 0.3981 - val_accuracy: 0.8878

# %%
loss, accuracy = net_Adam_na.evaluate(test_dataset)
# Out:
# 12/12 [==============================] - 2s 122ms/step - loss: 0.3529 - accuracy: 0.8683

# %%
# Visualization of the learning curves
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_Adam_na.history['loss'])
plt.plot(history_Adam_na.history['val_loss'])
plt.ylim([0.0, 2.0])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['train', 'valid'])
plt.title('Training and Validation Loss');

plt.subplot(1, 2, 2)
plt.plot(history_Adam_na.history['accuracy'])
plt.plot(history_Adam_na.history['val_accuracy'])
plt.ylim([0.5, 1.0])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'valid'])
plt.title('Training and Validation Accuracy');

# %% [markdown]
# # Net with optimizer RMSprop and different augmentation
# - lr: 0.001
# - reg 0.0001
# - dense:128

# %%
def random_channel_flip(image):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    return image

new_data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomTranslation(0.1, 0.1),
        layers.RandomContrast(0.2),
        layers.RandomBrightness(0.2),
        layers.GaussianNoise(0.1),
        layers.Lambda(random_channel_flip),

    ]
)




vgg_model = keras.applications.VGG16(input_shape=(224,224,3), weights='imagenet', include_top=False)


for layer in vgg_model.layers:
    layer.trainable = False

from keras import regularizers

inputs = keras.Input(shape=(224, 224, 3))
x = inputs
x = new_data_augmentation(x)
x = keras.applications.vgg16.preprocess_input(x)
x = vgg_model(x)

x = keras.layers.GlobalAveragePooling2D()(x)


x = keras.layers.BatchNormalization()(x)

x = keras.layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.0001))(x)
x = keras.layers.Dropout(0.5)(x)

outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
net_RMS_na = keras.Model(inputs=inputs, outputs=outputs)



# Compile the model
net_RMS_na.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.RMSprop(learning_rate=0.001),
              metrics=['accuracy'])


net_RMS_na.summary()

# train the model
history_RMS_na = net_RMS_na.fit(train_dataset,
          epochs=40,
          validation_data=val_dataset,
          callbacks=[callback])

net_RMS_na.save('drive/MyDrive/FDL/Vgg_RMS_na.h5')
# Out:
# Model: "model_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_44 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  sequential_2 (Sequential)   (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem_21  (None, 224, 224, 3)      0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_21 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d_21  (None, 512)              0
#   (GlobalAveragePooling2D)
#
#  batch_normalization_41 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_42 (Dense)            (None, 128)               65664
#
#  dropout_21 (Dropout)        (None, 128)               0
#
#  dense_43 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 14,783,045
# Trainable params: 67,333
# Non-trainable params: 14,715,712
# _________________________________________________________________
# Epoch 1/40
# 81/81 [==============================] - 17s 187ms/step - loss: 1.1766 - accuracy: 0.5980 - val_loss: 0.6657 - val_accuracy: 0.7825
# Epoch 2/40
# 81/81 [==============================] - 15s 175ms/step - loss: 0.7598 - accuracy: 0.7480 - val_loss: 0.5334 - val_accuracy: 0.8126
# Epoch 3/40
# 81/81 [==============================] - 15s 176ms/step - loss: 0.6211 - accuracy: 0.7889 - val_loss: 0.4794 - val_accuracy: 0.8495
# Epoch 4/40
# 81/81 [==============================] - 15s 178ms/step - loss: 0.5709 - accuracy: 0.8021 - val_loss: 0.4733 - val_accuracy: 0.8482
# Epoch 5/40
# 81/81 [==============================] - 15s 179ms/step - loss: 0.5199 - accuracy: 0.8274 - val_loss: 0.4606 - val_accuracy: 0.8509
# Epoch 6/40
# 81/81 [==============================] - 15s 178ms/step - loss: 0.4776 - accuracy: 0.8317 - val_loss: 0.4514 - val_accuracy: 0.8714
# Epoch 7/40
# 81/81 [==============================] - 15s 178ms/step - loss: 0.4922 - accuracy: 0.8352 - val_loss: 0.4212 - val_accuracy: 0.8591
# Epoch 8/40
# 81/81 [==============================] - 15s 180ms/step - loss: 0.4627 - accuracy: 0.8450 - val_loss: 0.4548 - val_accuracy: 0.8632
# Epoch 9/40
# 81/81 [==============================] - 17s 201ms/step - loss: 0.4584 - accuracy: 0.8446 - val_loss: 0.4499 - val_accuracy: 0.8591
# Epoch 10/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.4227 - accuracy: 0.8551 - val_loss: 0.4659 - val_accuracy: 0.8687
# Epoch 11/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.4337 - accuracy: 0.8524 - val_loss: 0.4837 - val_accuracy: 0.8632
# Epoch 12/40
# 81/81 [==============================] - 15s 181ms/step - loss: 0.4111 - accuracy: 0.8563 - val_loss: 0.4575 - val_accuracy: 0.8687

# %%
loss, accuracy = net_RMS_na.evaluate(test_dataset)
# Out:
# 12/12 [==============================] - 2s 125ms/step - loss: 0.3701 - accuracy: 0.8737

# %%
# Visualization of the learning curves
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_RMS_na.history['loss'])
plt.plot(history_RMS_na.history['val_loss'])
plt.ylim([0.0, 2.0])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['train', 'valid'])
plt.title('Training and Validation Loss');

plt.subplot(1, 2, 2)
plt.plot(history_RMS_na.history['accuracy'])
plt.plot(history_RMS_na.history['val_accuracy'])
plt.ylim([0.5, 1.0])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'valid'])
plt.title('Training and Validation Accuracy');

# %% [markdown]
# # Adam vs RMSprop with different type of augmentation

# %%
# Visualization of the learning curves
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(histories_Adam_dense[1].history['val_loss'], label='Adam, dense {}'.format(num_dense[1]))
plt.plot(histories_RMS_dense[1].history['val_loss'], label='RMS, dense {}'.format(num_dense[1]))
plt.plot(history_Adam_na.history['val_loss'], label='Adam, new augmentation')
plt.plot(history_RMS_na.history['val_loss'], label='RMS, new augmentation')
plt.ylim([0.0, 2.0])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Validation Loss');

plt.subplot(1, 2, 2)
plt.plot(histories_Adam_dense[1].history['val_accuracy'], label='Adam, dense {}'.format(num_dense[1]))
plt.plot(histories_RMS_dense[1].history['val_accuracy'], label='RMS, dense {}'.format(num_dense[1]))
plt.plot(history_Adam_na.history['val_accuracy'], label='Adam, new augmentation')
plt.plot(history_RMS_na.history['val_accuracy'], label='RMS, new augmentation')
plt.ylim([0.5, 1.0])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Validation Accuracy');

# %% [markdown]
# Best vgg model : optimizer=adam, lr=0.001, reg=0.0001, dense=128, base augmentation
